# %%
import numpy as np
import matplotlib.pyplot as plt
from   MRPy import MRPy
import numpy as np
import scipy.integrate as integrate
import gzip   as gz
import scipy as sc

# %% [markdown]
# ## VELOCIDADE ANGULAR DO SERVO

# %%
veloc_ang='leitura_excitador/2019-11-15__16-04-57'

with gz.open(veloc_ang+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]
    
a=MRPy.resampling(ti,(data[1:,1:])/32.8)

az   = MRPy(a[0], a.fs)
t    = a.t_axis()

plt.figure(4, figsize=(16, 4), clear=True)
plt.plot(t, az[0])

plt.xlim(11, 14);  plt.xlabel('Tempo (s)') 
plt.ylim(-750, 750);
plt.ylabel('Velocidade Angular (°/s)') 

plt.grid(True) 


plt.grid(True)

# %% [markdown]
# ## FREQUÊNCIA NATURAL

# %% [markdown]
# ### Primeira freq

# %%
filename='leitura_excitador/2019-11-15__16-34-07'

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]
    
a=MRPy.resampling(ti,10*(data[1:,1:]/8096))

az2   = MRPy(a[0], a.fs)
t    = a.t_axis()

az1   = MRPy(a[1], a.fs)
t    = a.t_axis()

plt.figure(4, figsize=(15, 4), clear=True)
plt.plot(t, az1[0])
plt.plot(t, az2[0])

#plt.xlim(0, az.Td);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);
plt.ylabel('a_z (m/s^2)') 

plt.grid(True)

Saz11, fs11 = az1.periodogram()
f11         = az1.f_axis()

Saz22, fs22 = az2.periodogram()
f22         = az2.f_axis()

#Saz21 = sc.signal.csd(az2,az1)
#Saz12 = sc.signal.csd(az1,az2)


plt.figure(5, figsize=(15, 4), clear=True)

plt.plot(f11, Saz11[0])
plt.plot(f22, Saz22[0])

plt.xlim(2, 10);   plt.xlabel('frequency (Hz)') 
#plt.ylim(0,  5);   plt.ylabel('S_az (power)') 

plt.grid(True)

# %% [markdown]
# ### Segunda freq

# %%
filename='leitura_excitador/2019-11-15__19-22-19'

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]
    
a=MRPy.resampling(ti,10*(data[1:,1:]/8096))

az2   = MRPy(a[0], a.fs)
t    = a.t_axis()

az1   = MRPy(a[1], a.fs)
t    = a.t_axis()

plt.figure(4, figsize=(15, 4), clear=True)
plt.plot(t, az1[0])
plt.plot(t, az2[0])

plt.xlim(0, 35);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);
plt.ylabel('a_z (m/s^2)') 

plt.grid(True)

Saz11, fs11 = az1.periodogram()
f11         = az1.f_axis()

Saz22, fs22 = az2.periodogram()
f22         = az2.f_axis()

#Saz21 = sc.signal.csd(az2,az1)
#Saz12 = sc.signal.csd(az1,az2)


plt.figure(5, figsize=(15, 4), clear=True)

plt.plot(f11, Saz11[0])
plt.plot(f22, Saz22[0])

plt.xlim(2, 11);   plt.xlabel('frequency (Hz)') 
#plt.ylim(0,  5);   plt.ylabel('S_az (power)') 

plt.grid(True)

# %% [markdown]
# ## Leitura Excitador

# %% [markdown]
# ### f = 9.45

# %%
filename='leitura_excitador/2019-11-15__18-53-09'

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]
    
a=MRPy.resampling(ti,10*(data[1:,1:]/8096))

az2   = MRPy(a[0], a.fs)
t    = a.t_axis()

az1   = MRPy(a[1], a.fs)
t    = a.t_axis()

plt.figure(4, figsize=(15, 4), clear=True)
plt.plot(t, az1[0])
plt.plot(t, az2[0])

plt.xlim(12, 21);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);
plt.ylabel('a_z (m/s^2)') 

plt.grid(True)

Saz11, fs11 = az1.periodogram()
f11         = az1.f_axis()

Saz22, fs22 = az2.periodogram()
f22         = az2.f_axis()

Saz21 = sc.signal.csd(az2,az1)
Saz12 = sc.signal.csd(az1,az2)


plt.figure(5, figsize=(15, 4), clear=True)

plt.plot(f11, Saz11[0])
plt.plot(f22, Saz22[0])

plt.xlim(9, 10);   plt.xlabel('frequency (Hz)') 
#plt.ylim(0,  5);   plt.ylabel('S_az (power)') 

plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-ce96a014d377> in <module>
#      30 f22         = az2.f_axis()
#      31
# ---> 32 Saz21 = sc.signal.csd(az2,az1)
#      33 Saz12 = sc.signal.csd(az1,az2)
#      34
#
# AttributeError: module 'scipy' has no attribute 'signal'

# %% [markdown]
#  ### f = 3,44

# %%
filename='leitura_excitador/2019-11-15__18-54-55'

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]
    
a=MRPy.resampling(ti,10*(data[1:,1:]/8096))

az2   = MRPy(a[0], a.fs)
t    = a.t_axis()

az1   = MRPy(a[1], a.fs)
t    = a.t_axis()

plt.figure(4, figsize=(15, 4), clear=True)
plt.plot(t, az1[0])
plt.plot(t, az2[0])

plt.xlim(12, 21);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);
plt.ylabel('a_z (m/s^2)') 

plt.grid(True)

Saz11, fs11 = az1.periodogram()
f11         = az1.f_axis()

Saz22, fs22 = az2.periodogram()
f22         = az2.f_axis()



plt.figure(5, figsize=(15, 4), clear=True)

plt.plot(f11, Saz11[0])
plt.plot(f22, Saz22[0])

plt.xlim(3, 4);   plt.xlabel('frequency (Hz)') 
#plt.ylim(0,  5);   plt.ylabel('S_az (power)') 

plt.grid(True)

# %%
freq=np.array([1.44,2.44,3.44,4.44,5.44,6.44,7.44,8.44,9.45])
print (freq[0])

# %% [markdown]
# ## Variando a freq.

# %% [markdown]
# f = 2.44, 3.44, 4.44, 5.44, 6.44, 7.44, 8.44, 9.45

# %%
filename='leitura_excitador/2019-11-15__20-00-42'     # Todas as frequências
filename1='leitura_excitador/2019-11-15__20-30-10'    # 2.44 Hz
filename2='leitura_excitador/2019-11-15__20-31-20'    # 3.44 Hz
filename3='leitura_excitador/2019-11-15__20-32-57'    # 4.44 Hz
filename4='leitura_excitador/2019-11-15__20-34-00'    # 5.44 Hz
filename5='leitura_excitador/2019-11-15__20-35-01'    # 6.44 Hz
filename6='leitura_excitador/2019-11-15__20-35-55'    # 7.44 Hz
filename7='leitura_excitador/2019-11-15__20-36-46'    # 8.44 Hz
filename8='leitura_excitador/2019-11-15__20-37-51'    # 9.45 Hz

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]
    
a=MRPy.resampling(ti,10*(data[1:,1:]/8096))

az2   = MRPy(a[0], a.fs)
t    = a.t_axis()
az1   = MRPy(a[1], a.fs)
t    = a.t_axis()

#FREQ. 2.44 Hz

plt.figure(4, figsize=(15, 4), clear=True)
plt.plot(t, az1[0])
plt.plot(t, az2[0])

plt.xlim(5,120);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);
plt.ylabel('a_z (m/s^2)') 

plt.grid(True)

Saz11, fs11 = az1.periodogram()
f11         = az1.f_axis()

Saz22, fs22 = az2.periodogram()
f22         = az2.f_axis()

x1=[2.425, 2.425]
x2=[3.39, 3.39]
x3=[4.37, 4.37]
x4=[2.425, 2.425]
y=[0,15]
plt.figure(5, figsize=(15, 4), clear=True)

plt.plot(f11, Saz11[0])
plt.plot(f22, Saz22[0])
plt.plot(x1, y)
plt.plot(x2, y)
plt.plot(x3, y)
plt.plot(x4, y)

plt.xlim(2, 10);   plt.xlabel('frequency (Hz)') 
plt.ylim(0,  12);   plt.ylabel('S_az (power)') 

plt.grid(True)
