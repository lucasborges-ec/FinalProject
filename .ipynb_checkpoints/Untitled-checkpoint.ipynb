# %%
# Importing Python modules required for this notebook
# (this cell must be executed with "shift+enter" before any other Python cell)

import numpy as np
import matplotlib.pyplot as plt
from   MRPy import MRPy
import numpy as np
import scipy.integrate as integrate
import gzip   as gz
import scipy as sc

# %%
import gzip   as gz


filename='Leitura_PI3_modeoff'

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]
    
a=MRPy.from_resampling(ti, data[1:,1:])

az   = MRPy(a[0], a.fs)
t    = a.t_axis()

plt.figure(4, figsize=(8, 4), clear=True)
plt.plot(t, az[0])

plt.xlim(0, az.Td);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);   plt.ylabel('a_z (m/s^2)') 

plt.grid(True) 


Saz, fs = az.periodogram()
f       = az.f_axis()

plt.figure(5, figsize=(8, 4), clear=True)
plt.plot(f, Saz[0])

plt.xlim(0, 10);   plt.xlabel('frequency (Hz)') 
plt.ylim(0,  5);   plt.ylabel('S_az (power)') 

plt.grid(True)

# %%
#v1 = integrate.quad(az[0],0,10)
v1=MRPy.integrate(az,band=(0,40))
t1=v1.t_axis()

u1=MRPy.integrate(v1,band=(0,40))
t2=u1.t_axis()

#print (v1)
plt.figure(6, figsize=(15, 4), clear=True)
#plt.plot(t,az[0]);
#plt.plot(t1,v1[0]);
plt.plot(t2,u1[0]);
plt.xlim(6, 50);   plt.xlabel('frequency (Hz)') 
#plt.ylim(-1,  1);   plt.ylabel('S_az (power)') 

plt.grid(True)

# %%
import numpy as np
from scipy import integrate
import matplotlib.pyplot as plt
# %matplotlib inline

def f(x):
    if (np.abs(x)<1e-10):
        res = x
    else:
        res = x*np.sin(1.0/x)
    return res

X = np.arange(-0.5,0.5,0.001)

plot(X,f(X))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0ac5f496fefd> in <module>
#      13 X = np.arange(-0.5,0.5,0.001)
#      14
# ---> 15 plot(X,f(X))
#
# NameError: name 'plot' is not defined

# %%
from sympy import sin, sqrt
from sympy.abc import x, n
from sympy.integrals import Integral
e = Integral(sin(x), (x, 3, 7))
e
Integral(sin(x), (x, 3, 7))

# %%
# Reads csv file with accelerometer signal and isolates component a_z




with open('2019-10-13__13-18-02.csv', 'rb') as target:
                
                    data1 =  np.genfromtxt(target, 
                                          delimiter=',',
                                          skip_header=1)
                    
                    ti1   =  data1[:,0]
                    
                    
with open('2019-10-13__13-16-36.csv', 'rb') as target:
                
                    data2 =  np.genfromtxt(target, 
                                          delimiter=',',
                                          skip_header=1)
                    
                    ti2   =  data2[:,0]

# %%
plt.figure(1, figsize=(20, 10), clear=True)
plt.xlim( 21, 22.75);   plt.xlabel('time (s)') 
plt.ylim(-2.0, 2.0);   plt.ylabel('displacement (mm)')
plt.grid(True)

d1=820
plt.plot(ti1[:-d1],data1[d1:,1]);

#plt.plot(ti1,data1[:,1]);
d2=1
plt.plot(ti2[:-d2],data2[d2:,1]);

print (np.size(ti1[:-d1]))
print (np.size(ti2[:-d2]))

# %% [markdown]
# ## PI 3

# %%
# Reads csv file with accelerometer signal and isolates component a_z

#data = MRPy.from_file('2019-10-13__09-48-46', form='MPU6050').zero_mean()
#print (data[0]) 


with open('Leitura_PI3_modeoff2.csv', 'rb') as target:
                
                    data1 =  np.genfromtxt(target, 
                                          delimiter=',',
                                          skip_header=1)
                    
                    ti1   =  data1[:,0]
                    
                    
with open('Leitura_PI3_modeon2.csv', 'rb') as target:
                
                    data2 =  np.genfromtxt(target, 
                                          delimiter=',',
                                          skip_header=1)
                    
                    ti2   =  data2[:,0]
                    
                    

a = MRPy.from_resampling(ti1[1:], data1[1:,1:])
tempo = t[2]-t[1]
v = np.zeros(np.size(a)-1)
print (a[:,1])


for i in range (a.size-1):
    v[i] = (a[:,i+1]+a[:,i])*tempo/2
    
for i in range (v.size-1):
    s[i] = (v[:,i+1]+v[:,i])    
    


az   = MRPy(a[0], a.fs)
t    = a.t_axis()
#print (az.Td/np.size())
print (t[2]-t[1])
# Out:
# [0.10908923]
# 0.0016169847061362121

# %%
plt.figure(1, figsize=(20, 10), clear=True)
plt.xlim( 3, 5);   plt.xlabel('time (s)') 
#plt.ylim(-.2, .2);   plt.ylabel('displacement (mm)')
plt.grid(True)

d1=1730
tempo1=ti1[:-d1]
ace1=data1[d1:,1]
plt.plot(tempo1,ace1);

#plt.plot(ti1,data1[:,1]);
d2=1
tempo2=ti2[:-d2]
ace2=data2[d2:,1]
plt.plot(tempo2,ace2);


print (np.size(ti1))
print (np.size(data1[1:,1:]))
print (ti1)


plt.figure(4, figsize=(15, 4), clear=True)
plt.plot(t, az[0])

plt.xlim(2.5, az.Td);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);   plt.ylabel('a_z (m/s^2)') 

plt.grid(True) 


Saz, fs = az.periodogram()
f       = az.f_axis()

plt.figure(5, figsize=(8, 4), clear=True)
plt.plot(f, Saz[0])

plt.xlim(2.5, 3.5);   plt.xlabel('frequency (Hz)') 
#plt.ylim(0,  1);
plt.ylabel('S_az (power)') 

plt.grid(True) 


#result_simps = integrate.(ace1, dx=0.2E-6)
#result_trapz = integrate.trapz(ace1, dx=0.2E-6)
#plt.plot(tempo1,result_simps);
# Out:
# 25000
# 24999
# [3.24249268e-05 1.87754631e-03 3.47495079e-03 ... 4.04200900e+01
#  4.04216762e+01 4.04232612e+01]

# %% [markdown]
# ## Decremento Logarítmico

# %%
t_max = 2
f = 10
n = 430

z=0.05
w=2*np.pi*f
t = np.linspace(0,t_max,n*t_max)
dec = np.exp(-(z*w*t))
plt.figure(2, figsize=(10,5), clear=True)
plt.plot(t, dec);

# %%
filename='excitacao_forcada'

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]
    
a=MRPy.from_resampling(ti, data[1:,1:])

az   = MRPy(a[0], a.fs)
t    = a.t_axis()

plt.figure(4, figsize=(15, 4), clear=True)
plt.plot(t, az[0])

plt.xlim(2.5, az.Td);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);   plt.ylabel('a_z (m/s^2)') 

plt.grid(True) 


Saz, fs = az.periodogram()
f       = az.f_axis()

plt.figure(5, figsize=(8, 4), clear=True)
plt.plot(f, Saz[0])

plt.xlim(0, 10);   plt.xlabel('frequency (Hz)') 
plt.ylim(0,  5);   plt.ylabel('S_az (power)') 

plt.grid(True)

# %% [markdown]
# ## LEITURA DE ACELERAÇÃO (a) E SERVO (s)

# %% [markdown]
# ### A = 900

# %%
filename='teste4_a_s'

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]


plt.figure(4, figsize=(15, 4), clear=True)
plt.plot(ti, data[1:,2])           #SERVO
plt.plot(ti, 900*data[1:,1]+1450)  #ACELERAÇÃO

#plt.xlim(0, 10);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);   plt.ylabel('a_z (m/s^2)') 

plt.grid(True)

# %% [markdown]
# ### A=1000

# %%
filename='teste5_a_s'

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]


plt.figure(4, figsize=(15, 4), clear=True)
plt.plot(ti, data[1:,2])           #SERVO
plt.plot(ti, 1000*data[1:,1]+1450)  #ACELERAÇÃO

plt.xlim(18, 24);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);   plt.ylabel('a_z (m/s^2)') 

plt.grid(True)

# %% [markdown]
# ### A=500

# %%
filename='teste6_a_s'

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]


plt.figure(4, figsize=(15, 4), clear=True)
plt.plot(ti, data[1:,2])           #SERVO
plt.plot(ti, 500*data[1:,1]+1450)  #ACELERAÇÃO

plt.xlim(12, 18);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);   plt.ylabel('a_z (m/s^2)') 

plt.grid(True)

# %% [markdown]
# ### A=300

# %%
filename='teste7_a_s'

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]


plt.figure(4, figsize=(15, 4), clear=True)
#plt.plot(ti, data[1:,2])           #SERVO
plt.plot(ti, data[1:,1])  #ACELERAÇÃO

plt.xlim(7, 11);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);   plt.ylabel('a_z (m/s^2)') 

plt.grid(True)

# %% [markdown]
# ### Set Middle

# %%
filename='teste8_a_s'

with gz.open(filename+'.csv.gz', 'rb') as target:
    data =  np.genfromtxt(target, 
                          delimiter=',')
    ti   =  data[1:,0] - data[1,0]


plt.figure(4, figsize=(15, 4), clear=True)
plt.plot(ti, data[1:,2])           #SERVO
plt.plot(ti, 300*data[1:,1]+1450)  #ACELERAÇÃO

plt.xlim(18, 25);  plt.xlabel('time (s)') 
#plt.ylim(-15, 15);   plt.ylabel('a_z (m/s^2)') 

plt.grid(True)

# %%
t_total = 3
n = 450
fn = 7
A = 600
sin_A=2
t = np.linspace(0,t_total,n*t_total)
y = sin_A*np.sin(2*np.pi*fn*t)

plt.figure(5, figsize=(15,5), clear=True)
plt.plot(t,y);
middle=1450
cs= (((middle+A)-(middle-A))*y-(sin_A)*((middle+A)+(middle-A)))/-(2*sin_A)
plt.figure(6, figsize=(15,5), clear=True)
plt.plot(t,cs);
